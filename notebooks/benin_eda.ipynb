# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/benin-malanville.csv')

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525600 entries, 0 to 525599
# Data columns (total 19 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Timestamp      525600 non-null  object
#  1   GHI            525600 non-null  float64
#  2   DNI            525600 non-null  float64
#  3   DHI            525600 non-null  float64
#  4   ModA           525600 non-null  float64
#  5   ModB           525600 non-null  float64
#  6   Tamb           525600 non-null  float64
#  7   RH             525600 non-null  float64
#  8   WS             525600 non-null  float64
#  9   WSgust         525600 non-null  float64
#  10  WSstdev        525600 non-null  float64
#  11  WD             525600 non-null  float64
#  12  WDstdev        525600 non-null  float64
#  13  BP             525600 non-null  int64
#  14  Cleaning       525600 non-null  int64
#  15  Precipitation  525600 non-null  float64
# ...

# %%
df.describe()
# Out:
#                  GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      240.559452     167.187516     115.358961     236.589496
# std       331.131327     261.710501     158.691074     326.894859
# min       -12.900000      -7.800000     -12.600000       0.000000
# 25%        -2.000000      -0.500000      -2.100000       0.000000
# 50%         1.800000      -0.100000       1.600000       4.500000
# 75%       483.400000     314.200000     216.300000     463.700000
# max      1413.000000     952.300000     759.200000    1342.300000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      228.883576      28.179683      54.487969       2.121113
# std       316.536515       5.924297      28.073069       1.603466
# min         0.000000      11.000000       2.100000       0.000000
# ...

# %%
df.isna().sum()
# Out:
# Timestamp             0
# GHI                   0
# DNI                   0
# DHI                   0
# ModA                  0
# ModB                  0
# Tamb                  0
# RH                    0
# WS                    0
# WSgust                0
# WSstdev               0
# WD                    0
# WDstdev               0
# BP                    0
# Cleaning              0
# Precipitation         0
# TModA                 0
# TModB                 0
# Comments         525600
# dtype: int64

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
plt.figure(figsize=(10,5))
plt.plot(df['Timestamp'], df['GHI'])
plt.title('Global Horizontal Irradiance Over Time - Benin')
plt.xlabel('Time')
plt.ylabel('GHI (W/m²)')
plt.show()

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
plt.figure(figsize=(10,5))
plt.plot(df['Timestamp'], df['DNI'])
plt.title('Direct Normal Irradiance Over Time - Benin')
plt.xlabel('Time')
plt.ylabel('DNI (W/m²)')
plt.show()

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
plt.figure(figsize=(10,5))
plt.plot(df['Timestamp'], df['DHI'])
plt.title('Diffuse Horizontal Irradiance Over Time - Benin')
plt.xlabel('Time')
plt.ylabel('DHI (W/m²)')
plt.show()
